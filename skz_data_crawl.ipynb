# %%
#import necessary libraries
import requests
import pandas as pd
import numpy as np
import re
from bs4 import BeautifulSoup
import string
import time
import random
import os
from string import ascii_lowercase
from urllib.request import urlopen
import json

# %%
BASE_URL = "https://api.genius.com"
CLIENT_ACCESS_TOKEN  = '5Gm9G1n9_B2suKi82vgBgG45AFmVOTvFClR1vaKgR-5FveAEJQIG5uQ3do0ccQxw'
ARTIST_NAME  = "Stray Kids"

# %%
genius_search_url = f"http://api.genius.com/search?q={ARTIST_NAME}&access_token={CLIENT_ACCESS_TOKEN}"
response = requests.get(genius_search_url)
json_data = response.json()

# %%
#to get song information on Genius, I will use their API. We will get all song data like song title, album, author, releasedate and put them into a csv file
def _get(path, params=None, headers=None):

    # generate request URL
    requrl = '/'.join([BASE_URL, path])
    token = "Bearer {}".format(CLIENT_ACCESS_TOKEN)
    if headers:
        headers['Authorization'] = token
    else:
        headers = {"Authorization": token}

    response = requests.get(url=requrl, params=params, headers=headers)
    response.raise_for_status()

    return response.json()
def get_artist_songs(artist_id):
    # initialize variables & a list.
    current_page = 1
    next_page = True
    songs = []

    while next_page:

        path = "artists/{}/songs/".format(artist_id)
        params = {'page': current_page}
        data = _get(path=path, params=params)

        page_songs = data['response']['songs']

        if page_songs:
            # add all the songs of current page,
            # and increment current_page value for next loop.
            songs += page_songs
            current_page += 1
        else:
            # if page_songs is empty, quit.
            next_page = False

    # get all the song ids, excluding not-primary-artist songs.
    songs = [song["id"] for song in songs
            if song["primary_artist"]["id"] == artist_id]

    return songs

def get_song_information(song_ids):
    song_list = {}

    for i, song_id in enumerate(song_ids):
        print("id:" + str(song_id) + " start. ->")

        path = "songs/{}".format(song_id)
        data = _get(path=path)["response"]["song"]

        song_list.update({
        i: {
            "title": data["title"],
            "album": data["album"]["name"] if data["album"] else "<single>",
            "release_date": data["release_date"] if data["release_date"] else "unidentified",
            "featured_artists":
                [feat["name"] if data["featured_artists"] else "" for feat in data["featured_artists"]],
            "producer_artists":
                [feat["name"] if data["producer_artists"] else "" for feat in data["producer_artists"]],
            "writer_artists":
                [feat["name"] if data["writer_artists"] else "" for feat in data["writer_artists"]],
            "genius_track_id": song_id,
            "genius_album_id": data["album"]["id"] if data["album"] else "none"}
        })

        print("-> id:" + str(song_id) + " is finished. \n")
    return song_list

# %%
print("searching " + ARTIST_NAME + "'s artist id. \n")

# find artist id from given data.
find_id = _get("search", {'q': ARTIST_NAME})
for hit in find_id["response"]["hits"]:
   if hit["result"]["primary_artist"]["name"] == ARTIST_NAME:
       artist_id = hit["result"]["primary_artist"]["id"]
       break

print("-> " + ARTIST_NAME + "'s id is " + str(artist_id) + "\n")

print("getting song ids. \n")
# get all song ids and make a list.
song_ids = get_artist_songs(artist_id)

print("\n-> got all the song ids. \n")
# Out:
# searching Stray Kids's artist id.
#
# -> Stray Kids's id is 1233909
#
# getting song ids.
#
# [4007652, 7514244, 4381674, 7553398, 7402682, 8377160, 3581047, 7514241, 3399347, 7294057, 5645652, 6002793, 6198384, 10351728, 5645653, 5916025, 9526960, 4908282, 3581044, 7514239, 3863576, 7553312, 5928194, 6002867, 9626946, 8732242, 7514217, 3399342, 7513916, 9600872, 5645655, 5928195, 5066765, 4381654, 7513909, 7514219, 9365243, 9365245, 7183912, 8377162, 8377155, 8641097, 7758320, 7066626, 8377157, 8732246, 7376267, 4381655, 7553393, 8005225, 8377163, 9072333, 9600873, 9600874, 9797162, 9611861, 3581039, 7553266, 9072325, 8732244, 7095802, 7402684, 4908280, 7518224, 5172320, 5361397, 5645650, 4381651, 5928196, 8005226, 6002905, 8644103, 6420802, 9072334, 7514218, 7758321, 4007650, 7553338, 9072326, 8377158, 3399345, 6828989, 7052539, 5637916, 3581046, 7553273, 9072318, 5645657, 3265614, 7513855, 5771870, 6919298, 4007649, 8398594, 7514220, 4006811, 7513892, 6756990, 3863574, 7514246, 7806866, 9072320, 9600875, 5066763, 5172334, 7758322, 10287306, 10298290, 10387923, 10387911, 8732243, 7541741, 7758318, 8005228, 8394171, 4381653, 7514245, 9162351, 9600869, 3863575, 7553285, 4381643, 7513859, 3581043, 7513927, 3581048, 4307233, 4011560, 4381656, 5066767, 5127917, 6948030, 5386587, 8252839, 7758324, 6881808, 3863568, 5361398, 7553278, 4007648, 7514242, 5924893, 5113331, 6919304, 3581042, 8732245, 4007651, 7514243, 7811504, 6002908, 5645651, 9362034, 5645654, 7514216, 3863573, 7553280, 7052536, 4608448, 3581045, 7514240, 7183891, 7514180, 3399346, 9072319, 7095807, 4603431, 7513876, 7095806, 8005229, 5563966, 5566852, 5555215, 5414909, 5555226, 9365236, 9365244, 9600876, 7095805, 3399343, 7553226, 7095803, 7095808, 5066762, 9127068, 5066766, 8377159, 9072321, 9365237, 7052538, 5645656, 8377161, 8732247, 8732241, 8732248, 9072336, 5928193, 7095804, 7095801, 7183892, 4608462, 7553411, 5563965, 5566840, 5555214, 5414868, 5555225, 9072324, 6924822, 7758319, 4381652, 7513912, 3863572, 7513872, 7758323, 5924891, 3863571, 10196800, 7402683, 6852681, 7134120, 5924892, 3399344, 7553231, 4007647, 5066764, 8005230, 9072335, 9600870, 9600877, 5645649, 6002849, 8005227, 5361396]
#
# -> got all the song ids. take a break for a while

# %%
song_metadata = get_song_information(song_ids)
# Out:
# id:4007652 start. ->
# -> id:4007652 is finished.
#
# id:7514244 start. ->
# -> id:7514244 is finished.
#
# id:4381674 start. ->
# -> id:4381674 is finished.
#
# id:7553398 start. ->
# -> id:7553398 is finished.
#
# id:7402682 start. ->
# -> id:7402682 is finished.
#
# id:8377160 start. ->
# -> id:8377160 is finished.
#
# id:3581047 start. ->
# -> id:3581047 is finished.
#
# id:7514241 start. ->
# -> id:7514241 is finished.
#
# id:3399347 start. ->
# -> id:3399347 is finished.
#
# id:7294057 start. ->
# -> id:7294057 is finished.
#
# id:5645652 start. ->
# -> id:5645652 is finished.
#
# id:6002793 start. ->
# -> id:6002793 is finished.
#
# id:6198384 start. ->
# -> id:6198384 is finished.
#
# id:10351728 start. ->
# -> id:10351728 is finished.
#
# id:5645653 start. ->
# -> id:5645653 is finished.
#
# id:5916025 start. ->
# -> id:5916025 is finished.
#
# id:9526960 start. ->
# -> id:9526960 is finished.
#
# id:4908282 start. ->
# -> id:4908282 is finished.
#
# id:3581044 start. ->
# -> id:3581044 is finished.
#
# id:7514239 start. ->
# -> id:7514239 is finished.
#
# id:3863576 start. ->
# -> id:3863576 is finished.
#
# id:7553312 start. ->
# -> id:7553312 is finished.
#
# id:5928194 start. ->
# -> id:5928194 is finished.
#
# id:6002867 start. ->
# -> id:6002867 is finished.
#
# id:9626946 start. ->
# -> id:9626946 is finished.
#
# id:8732242 start. ->
# -> id:8732242 is finished.
#
# id:7514217 start. ->
# -> id:7514217 is finished.
#
# id:3399342 start. ->
# -> id:3399342 is finished.
#
# id:7513916 start. ->
# -> id:7513916 is finished.
#
# id:9600872 start. ->
# -> id:9600872 is finished.
#
# id:5645655 start. ->
# -> id:5645655 is finished.
#
# id:5928195 start. ->
# -> id:5928195 is finished.
#
# id:5066765 start. ->
# -> id:5066765 is finished.
#
# id:4381654 start. ->
# -> id:4381654 is finished.
#
# id:7513909 start. ->
# -> id:7513909 is finished.
#
# id:7514219 start. ->
# -> id:7514219 is finished.
#
# id:9365243 start. ->
# -> id:9365243 is finished.
#
# id:9365245 start. ->
# -> id:9365245 is finished.
#
# id:7183912 start. ->
# -> id:7183912 is finished.
#
# id:8377162 start. ->
# -> id:8377162 is finished.
#
# id:8377155 start. ->
# -> id:8377155 is finished.
#
# id:8641097 start. ->
# -> id:8641097 is finished.
#
# id:7758320 start. ->
# -> id:7758320 is finished.
#
# id:7066626 start. ->
# -> id:7066626 is finished.
#
# id:8377157 start. ->
# -> id:8377157 is finished.
#
# id:8732246 start. ->
# -> id:8732246 is finished.
#
# id:7376267 start. ->
# -> id:7376267 is finished.
#
# id:4381655 start. ->
# -> id:4381655 is finished.
#
# id:7553393 start. ->
# -> id:7553393 is finished.
#
# id:8005225 start. ->
# -> id:8005225 is finished.
#
# id:8377163 start. ->
# -> id:8377163 is finished.
#
# id:9072333 start. ->
# -> id:9072333 is finished.
#
# id:9600873 start. ->
# -> id:9600873 is finished.
#
# id:9600874 start. ->
# -> id:9600874 is finished.
#
# id:9797162 start. ->
# -> id:9797162 is finished.
#
# id:9611861 start. ->
# -> id:9611861 is finished.
#
# id:3581039 start. ->
# -> id:3581039 is finished.
#
# id:7553266 start. ->
# -> id:7553266 is finished.
#
# id:9072325 start. ->
# -> id:9072325 is finished.
#
# id:8732244 start. ->
# -> id:8732244 is finished.
#
# id:7095802 start. ->
# -> id:7095802 is finished.
#
# id:7402684 start. ->
# -> id:7402684 is finished.
#
# id:4908280 start. ->
# -> id:4908280 is finished.
#
# id:7518224 start. ->
# -> id:7518224 is finished.
#
# id:5172320 start. ->
# -> id:5172320 is finished.
#
# id:5361397 start. ->
# -> id:5361397 is finished.
#
# id:5645650 start. ->
# -> id:5645650 is finished.
#
# id:4381651 start. ->
# -> id:4381651 is finished.
#
# id:5928196 start. ->
# -> id:5928196 is finished.
#
# id:8005226 start. ->
# -> id:8005226 is finished.
#
# id:6002905 start. ->
# -> id:6002905 is finished.
#
# id:8644103 start. ->
# -> id:8644103 is finished.
#
# id:6420802 start. ->
# -> id:6420802 is finished.
#
# id:9072334 start. ->
# -> id:9072334 is finished.
#
# id:7514218 start. ->
# -> id:7514218 is finished.
#
# id:7758321 start. ->
# -> id:7758321 is finished.
#
# id:4007650 start. ->
# -> id:4007650 is finished.
#
# id:7553338 start. ->
# -> id:7553338 is finished.
#
# id:9072326 start. ->
# -> id:9072326 is finished.
#
# id:8377158 start. ->
# -> id:8377158 is finished.
#
# id:3399345 start. ->
# -> id:3399345 is finished.
#
# id:6828989 start. ->
# -> id:6828989 is finished.
#
# id:7052539 start. ->
# -> id:7052539 is finished.
#
# id:5637916 start. ->
# -> id:5637916 is finished.
#
# id:3581046 start. ->
# -> id:3581046 is finished.
#
# id:7553273 start. ->
# -> id:7553273 is finished.
#
# id:9072318 start. ->
# -> id:9072318 is finished.
#
# id:5645657 start. ->
# -> id:5645657 is finished.
#
# id:3265614 start. ->
# -> id:3265614 is finished.
#
# id:7513855 start. ->
# -> id:7513855 is finished.
#
# id:5771870 start. ->
# -> id:5771870 is finished.
#
# id:6919298 start. ->
# -> id:6919298 is finished.
#
# id:4007649 start. ->
# -> id:4007649 is finished.
#
# id:8398594 start. ->
# -> id:8398594 is finished.
#
# id:7514220 start. ->
# -> id:7514220 is finished.
#
# id:4006811 start. ->
# -> id:4006811 is finished.
#
# id:7513892 start. ->
# -> id:7513892 is finished.
#
# id:6756990 start. ->
# -> id:6756990 is finished.
#
# id:3863574 start. ->
# -> id:3863574 is finished.
#
# id:7514246 start. ->
# -> id:7514246 is finished.
#
# id:7806866 start. ->
# -> id:7806866 is finished.
#
# id:9072320 start. ->
# -> id:9072320 is finished.
#
# id:9600875 start. ->
# -> id:9600875 is finished.
#
# id:5066763 start. ->
# -> id:5066763 is finished.
#
# id:5172334 start. ->
# -> id:5172334 is finished.
#
# id:7758322 start. ->
# -> id:7758322 is finished.
#
# id:10287306 start. ->
# -> id:10287306 is finished.
#
# id:10298290 start. ->
# -> id:10298290 is finished.
#
# id:10387923 start. ->
# -> id:10387923 is finished.
#
# id:10387911 start. ->
# -> id:10387911 is finished.
#
# id:8732243 start. ->
# -> id:8732243 is finished.
#
# id:7541741 start. ->
# -> id:7541741 is finished.
#
# id:7758318 start. ->
# -> id:7758318 is finished.
#
# id:8005228 start. ->
# -> id:8005228 is finished.
#
# id:8394171 start. ->
# -> id:8394171 is finished.
#
# id:4381653 start. ->
# -> id:4381653 is finished.
#
# id:7514245 start. ->
# -> id:7514245 is finished.
#
# id:9162351 start. ->
# -> id:9162351 is finished.
#
# id:9600869 start. ->
# -> id:9600869 is finished.
#
# id:3863575 start. ->
# -> id:3863575 is finished.
#
# id:7553285 start. ->
# -> id:7553285 is finished.
#
# id:4381643 start. ->
# -> id:4381643 is finished.
#
# id:7513859 start. ->
# -> id:7513859 is finished.
#
# id:3581043 start. ->
# -> id:3581043 is finished.
#
# id:7513927 start. ->
# -> id:7513927 is finished.
#
# id:3581048 start. ->
# -> id:3581048 is finished.
#
# id:4307233 start. ->
# -> id:4307233 is finished.
#
# id:4011560 start. ->
# -> id:4011560 is finished.
#
# id:4381656 start. ->
# -> id:4381656 is finished.
#
# id:5066767 start. ->
# -> id:5066767 is finished.
#
# id:5127917 start. ->
# -> id:5127917 is finished.
#
# id:6948030 start. ->
# -> id:6948030 is finished.
#
# id:5386587 start. ->
# -> id:5386587 is finished.
#
# id:8252839 start. ->
# -> id:8252839 is finished.
#
# id:7758324 start. ->
# -> id:7758324 is finished.
#
# id:6881808 start. ->
# -> id:6881808 is finished.
#
# id:3863568 start. ->
# -> id:3863568 is finished.
#
# id:5361398 start. ->
# -> id:5361398 is finished.
#
# id:7553278 start. ->
# -> id:7553278 is finished.
#
# id:4007648 start. ->
# -> id:4007648 is finished.
#
# id:7514242 start. ->
# -> id:7514242 is finished.
#
# id:5924893 start. ->
# -> id:5924893 is finished.
#
# id:5113331 start. ->
# -> id:5113331 is finished.
#
# id:6919304 start. ->
# -> id:6919304 is finished.
#
# id:3581042 start. ->
# -> id:3581042 is finished.
#
# id:8732245 start. ->
# -> id:8732245 is finished.
#
# id:4007651 start. ->
# -> id:4007651 is finished.
#
# id:7514243 start. ->
# -> id:7514243 is finished.
#
# id:7811504 start. ->
# -> id:7811504 is finished.
#
# id:6002908 start. ->
# -> id:6002908 is finished.
#
# id:5645651 start. ->
# -> id:5645651 is finished.
#
# id:9362034 start. ->
# -> id:9362034 is finished.
#
# id:5645654 start. ->
# -> id:5645654 is finished.
#
# id:7514216 start. ->
# -> id:7514216 is finished.
#
# id:3863573 start. ->
# -> id:3863573 is finished.
#
# id:7553280 start. ->
# -> id:7553280 is finished.
#
# id:7052536 start. ->
# -> id:7052536 is finished.
#
# id:4608448 start. ->
# -> id:4608448 is finished.
#
# id:3581045 start. ->
# -> id:3581045 is finished.
#
# id:7514240 start. ->
# -> id:7514240 is finished.
#
# id:7183891 start. ->
# -> id:7183891 is finished.
#
# id:7514180 start. ->
# -> id:7514180 is finished.
#
# id:3399346 start. ->
# -> id:3399346 is finished.
#
# id:9072319 start. ->
# -> id:9072319 is finished.
#
# id:7095807 start. ->
# -> id:7095807 is finished.
#
# id:4603431 start. ->
# -> id:4603431 is finished.
#
# id:7513876 start. ->
# -> id:7513876 is finished.
#
# id:7095806 start. ->
# -> id:7095806 is finished.
#
# id:8005229 start. ->
# -> id:8005229 is finished.
#
# id:5563966 start. ->
# -> id:5563966 is finished.
#
# id:5566852 start. ->
# -> id:5566852 is finished.
#
# id:5555215 start. ->
# -> id:5555215 is finished.
#
# id:5414909 start. ->
# -> id:5414909 is finished.
#
# id:5555226 start. ->
# -> id:5555226 is finished.
#
# id:9365236 start. ->
# -> id:9365236 is finished.
#
# id:9365244 start. ->
# -> id:9365244 is finished.
#
# id:9600876 start. ->
# -> id:9600876 is finished.
#
# id:7095805 start. ->
# -> id:7095805 is finished.
#
# id:3399343 start. ->
# -> id:3399343 is finished.
#
# id:7553226 start. ->
# -> id:7553226 is finished.
#
# id:7095803 start. ->
# -> id:7095803 is finished.
#
# id:7095808 start. ->
# -> id:7095808 is finished.
#
# id:5066762 start. ->
# -> id:5066762 is finished.
#
# id:9127068 start. ->
# -> id:9127068 is finished.
#
# id:5066766 start. ->
# -> id:5066766 is finished.
#
# id:8377159 start. ->
# -> id:8377159 is finished.
#
# id:9072321 start. ->
# -> id:9072321 is finished.
#
# id:9365237 start. ->
# -> id:9365237 is finished.
#
# id:7052538 start. ->
# -> id:7052538 is finished.
#
# id:5645656 start. ->
# -> id:5645656 is finished.
#
# id:8377161 start. ->
# -> id:8377161 is finished.
#
# id:8732247 start. ->
# -> id:8732247 is finished.
#
# id:8732241 start. ->
# -> id:8732241 is finished.
#
# id:8732248 start. ->
# -> id:8732248 is finished.
#
# id:9072336 start. ->
# -> id:9072336 is finished.
#
# id:5928193 start. ->
# -> id:5928193 is finished.
#
# id:7095804 start. ->
# -> id:7095804 is finished.
#
# id:7095801 start. ->
# -> id:7095801 is finished.
#
# id:7183892 start. ->
# -> id:7183892 is finished.
#
# id:4608462 start. ->
# -> id:4608462 is finished.
#
# id:7553411 start. ->
# -> id:7553411 is finished.
#
# id:5563965 start. ->
# -> id:5563965 is finished.
#
# id:5566840 start. ->
# -> id:5566840 is finished.
#
# id:5555214 start. ->
# -> id:5555214 is finished.
#
# id:5414868 start. ->
# -> id:5414868 is finished.
#
# id:5555225 start. ->
# -> id:5555225 is finished.
#
# id:9072324 start. ->
# -> id:9072324 is finished.
#
# id:6924822 start. ->
# -> id:6924822 is finished.
#
# id:7758319 start. ->
# -> id:7758319 is finished.
#
# id:4381652 start. ->
# -> id:4381652 is finished.
#
# id:7513912 start. ->
# -> id:7513912 is finished.
#
# id:3863572 start. ->
# -> id:3863572 is finished.
#
# id:7513872 start. ->
# -> id:7513872 is finished.
#
# id:7758323 start. ->
# -> id:7758323 is finished.
#
# id:5924891 start. ->
# -> id:5924891 is finished.
#
# id:3863571 start. ->
# -> id:3863571 is finished.
#
# id:10196800 start. ->
# -> id:10196800 is finished.
#
# id:7402683 start. ->
# -> id:7402683 is finished.
#
# id:6852681 start. ->
# -> id:6852681 is finished.
#
# id:7134120 start. ->
# -> id:7134120 is finished.
#
# id:5924892 start. ->
# -> id:5924892 is finished.
#
# id:3399344 start. ->
# -> id:3399344 is finished.
#
# id:7553231 start. ->
# -> id:7553231 is finished.
#
# id:4007647 start. ->
# -> id:4007647 is finished.
#
# id:5066764 start. ->
# -> id:5066764 is finished.
#
# id:8005230 start. ->
# -> id:8005230 is finished.
#
# id:9072335 start. ->
# -> id:9072335 is finished.
#
# id:9600870 start. ->
# -> id:9600870 is finished.
#
# id:9600877 start. ->
# -> id:9600877 is finished.
#
# id:5645649 start. ->
# -> id:5645649 is finished.
#
# id:6002849 start. ->
# -> id:6002849 is finished.
#
# id:8005227 start. ->
# -> id:8005227 is finished.
#
# id:5361396 start. ->
# -> id:5361396 is finished.

# %%
song_info_res = pd.DataFrame(columns = ['songid','artist','title','releasedate','album'])
for i in range(len(song_metadata)):
    num =i+1
    songid = num
    artist = ', '.join(song_metadata[i]['writer_artists'])
    title = song_metadata[i]['title']
    releasedate = song_metadata[i]['release_date']
    album = song_metadata[i]['album']
    song_info_single = {'songid':songid,
                'artist':artist,
                'title':title,
                'releasedate':releasedate,
                'album':album
                }
    song_info_res.loc[len(song_info_res)]=song_info_single

# %%
song_info_res_cleaned =song_info_res.sort_values('releasedate').iloc[:-1]
song_info_res_cleaned['songid'] = list(range(1,len(song_info_res_cleaned)+1))
song_info_res_cleaned.to_csv('song_info.csv')
song_info_res_cleaned
# Out:
#      songid                                             artist  \
# 88        1  아르마딜로 (Armadillo), BANG CHAN, CHANGBIN, HAN (S...
# 183       2                                         Stray Kids
# 80        3  CHANGBIN, FELIX (Stray Kids), LEE KNOW, BANG C...
# 27        4  원택 (1Take) (KOR), Trippy (트리피), HAN (Stray Kid...
# 221       5  HAN (Stray Kids), CHANGBIN, BANG CHAN, ​earattack
# ..      ...                                                ...
# 216     228  BANG CHAN, CHANGBIN, HAN (Stray Kids), D&H (PU...
# 106     229  Charlie Puth, Jacob Kasher, Naliya, BANG CHAN,...
# 107     230  Charlie Puth, BANG CHAN, CHANGBIN, HAN (Stray ...
# 109     231  Charlie Puth, Jacob Kasher, Naliya, Johnny Gol...
# 108     232
#
#                                                title releasedate  \
# 88                                        Hellevator  2017-11-01
# 183  Stray Kids - Hellevator (Traducción al Español)  2017-11-01
# 80                                              GLOW  2018-01-08
# 27                              BEWARE (Grrr 총량의 법칙)  2018-01-08
# 221                                           YAYAYA  2018-01-08
# ..                                               ...         ...
# 216                                             WHY?  2024-04-12
# 106                                   Lose My Breath  2024-05-10
# 107                    Lose My Breath (Instrumental)  2024-05-10
# 109                 Lose My Breath (Stray Kids Ver.)  2024-05-13
# 108                Lose My Breath (Soft Garage Ver.)  2024-05-13
#
#                         album
# 88                    Mixtape
# 183                  <single>
# 80                    Mixtape
# 27                    Mixtape
# 221                   Mixtape
# ..                        ...
# 216                  <single>
# 106            Lose My Breath
# 107            Lose My Breath
# 109  Lose My Breath (Remixes)
# 108  Lose My Breath (Remixes)
#
# [232 rows x 5 columns]

# %% [markdown]
# Next, we are going to get lyrics from the website azlyrics using beautifulsoup. Originally, I wanted to get my lyrics from Genius but they don't let you download lyrics from their website because it's an infringement of copyrights. They have the robot checking procedure and I can't bypass that. Therefore, I go to azlyrics. Actually, azlyrics don't let you download their lyrics either. I couldn't extract the lyrics just by using beautifulsoup or maybe there was a way but I don't know how. The normal way of getting text div didn't return anything. So I decided to cast the result I got from beautifulsoup to string and used regex to extract the lyrics.
#
# I extracted the lyrics of their 217 ish songs and put them in a csv file

# %%
def get_lyrics(song_url):
    rt = random.randint(5, 15)
    song = urlopen(song_url)
    soupp = BeautifulSoup(song.read(), "html.parser")
    # Convert the BeautifulSoup object to a string
    html_string = str(soupp)

    # Define a regular expression pattern to match the desired content
    pattern = r'<!-- Usage of azlyrics\.com content by any third-party lyrics provider is prohibited by our licensing agreement\. Sorry about that\. -->(.*?)</div>'

    # Use re.findall to extract the content
    matches = re.findall(pattern, html_string, re.DOTALL)

    # Check if any matches are found
    if matches:
        extracted_content = matches[0]
    else:
        extracted_content = "Content not found."
    #use regex
    #clean the lyrics from special characters and linebreaks
    # Remove <br/>, </i>, [, ], and :
    cleaned_content = re.sub(r'<br\s*/?>|</i>', '', extracted_content)
    cleaned_content = cleaned_content.replace('[', '').replace(']', '').replace(':', '')
    time.sleep(rt)
    return cleaned_content

# %%
'''
Get all links of lyrics in SKZ discography on azlyrics
'''
az_url='https://www.azlyrics.com/s/straykids.html'

home = "https://www.azlyrics.com/"
main_page = urlopen(az_url)
bs = BeautifulSoup(main_page.read(), "html.parser")
divs = bs.find_all('div', {"class": "listalbum-item"})
urls = list()
for d in divs:
    try:
        urls.append(home + d.a['href'].split("/", 1)[1])
    except TypeError:
        print(d)
# Out:
# <div class="listalbum-item">Entrance<div class="comment">(Instrumental)</div></div>

# %%
# url_sample = urls[0:2]
dic_csv = {}
for url in urls[133:]:
    try:
        lyrics = get_lyrics(song_url = url)
        name = url.split('/')[-1].split('.')[0]
        dic_csv[name]=lyrics
    except:
        print(url)

# %% [markdown]
# There was an error in the results, where they couldn't get lyrics from an album called instrumental. I guess that's fair.

# %%
urls_error = ['https://www.azlyrics.com/lyrics/3racha/zone.html',
'https://www.azlyrics.com/lyrics/3racha/happy.html',
'https://www.azlyrics.com/lyrics/lildurk/allmylifestraykidsremix.html',
'https://www.azlyrics.com/lyrics/seungmin/destiny.html',
'https://www.azlyrics.com/lyrics/alesso/goingdumb.html',
'https://www.azlyrics.com/lyrics/jypark/likemagic.html']
for url in urls_error:
    try:
        lyrics = get_lyrics(song_url = url)
        name = url.split('/')[-1].split('.')[0]
        dic_csv[name]=lyrics
    except:
        print(url)

# %%
print('number of song lyrics crawled: ',len(dic_csv))
# Out:
# 217

# %%
file_path = 'song_lyrics.json'
with open(file_path, 'a') as json_file:
    json.dump(dic_csv, json_file, indent=4)

print(f"Dictionary successfully written to {file_path}")
# Out:
# Dictionary successfully written to song_lyrics.json

# %%
# Specify the file path
file_path = 'song_lyrics.json'

# Reading JSON data from a file
with open(file_path, 'r') as json_file:
    data = json.load(json_file)

# %%
#Get only the English lyrics
engtrans_res_ = pd.DataFrame(columns = ['song','lyrics'])
for i in data.keys():
    temp = {}
    temp['song'] = i
    L = data[i] 
    if '<i>English translation' in L:
        La = L.split('<i>English translation')[1]
        
    #if there's no english translation, take the original instead (the Korean/the Japanese lyrics). or if there's no Kor/Jap, take the original lyrics bc it's an English song
    else:
        if ('<i>Korean' in L):
            La = L.split('<i>Korean')[1]
            
        elif ('<i>Japanese' in L):
            La = L.split('<i>Japanese')[1]
        else:
            La = L
    # La = La.replace('\n', ' .').lower()
    La = re.sub(r"[^A-Za-z\n']", ' ', La)

    La = La.replace("\n\n", "\n")
    if La.startswith("\n"):
        La = La[1:]
    La = La.replace("\n",". ")
    temp['lyrics'] = La
    
    engtrans_res_.loc[len(engtrans_res_)] = temp

# %%
print('Final dataframe of song lyrics: ')
engtrans_res_.to_csv('eng_skz_lyrics.csv')
engtrans_res_
# Out:
# Final dataframe of song lyrics:
#                           song  \
# 0                   hellevator
# 1    grrrlawoftotalmadnessgrrr
# 2                spreadmywings
# 3                       yayaya
# 4                         glow
# ..                         ...
# 212                      happy
# 213    allmylifestraykidsremix
# 214                    destiny
# 215                  goingdumb
# 216                  likemagic
#
#                                                 lyrics
# 0    My life was rock bottom  an edge of a cliff. I...
# 1    Law of total madness. Grrr  my mind is a mess....
# 2    I didn't wanna seem young. So I just kept chan...
# 3    Stray Kids. Watch out.     . Yaya yaya yaya. Y...
# 4    We can rest but it's still too early. We need ...
# ..                                                 ...
# 212  I have no more chances. So I feel sad right no...
# 213  All my life  I've been runnin' alone. Space an...
# 214  Was our meeting a coincidence . No  I believe ...
# 215  Yeah. Feels like love     .                   ...
# 216  Is there anything that I couldn't give you .  ...
#
# [217 rows x 2 columns]

# %% [markdown]
# Now let's fix the mismatch between our song lyrics dataframe and song info. Azlyrics doesn't have detailed information about writer credit of the songs, they only have Stray Kids as general artist so we had to go on Genius to get the song credit information, but they had the song title saved differently than Azlyrics. Therefore we have to find a way for the two information to match.

# %%
clean_need = pd.read_csv('song_info.csv',index_col =0)

# %%
def clean_text(text):
    text = text.lower()  # Convert to lowercase
    text = re.sub(r'[^a-z0-9]', '', text)  # Eliminate non-alphabet characters
    text = text.replace(' ', '')  # Delete spaces
    return text

# Apply the cleaning function to the column
cleaned_title = clean_need['title'].apply(clean_text).values #title from genius, cleaned
og_title =engtrans_res_['song'].values #title from azlyrics

# %% [markdown]
# The song information from Genius is songs from Skz-record, collab songs and some songs doesn't appear because of mismatch between "ver" and "version". There's also some small difference in their earlier songs as well. I went back and fixed them manually.
#
# As Genius didn't give information about the tracks in Skz-record, we will enter these songs into song info dataframe manually too.

# %% [markdown]
# This is the result of our data retrieval step. Two tables, one table show song information and one contains song lyrics (english translation & english lyrics).

# %%
# df_cleaned.to_csv('song_info_cleaned_manual_1.csv')

# %%
print('Final result: ')
pd.read_csv('song_info_cleaned_manual_1.csv',index_col =0)
# Out:
# Final result:
#      songid                                             artist  \
# 0         1  아르마딜로 (Armadillo), BANG CHAN, CHANGBIN, HAN (S...
# 1         2  CHANGBIN, FELIX (Stray Kids), LEE KNOW, BANG C...
# 2         3  원택 (1Take) (KOR), Trippy (트리피), HAN (Stray Kid...
# 3         4  HAN (Stray Kids), CHANGBIN, BANG CHAN, ​earattack
# 4         5  BANG CHAN, CHANGBIN, HAN (Stray Kids), Trippy ...
# ..      ...                                                ...
# 272     273                                   HAN (Stray Kids)
# 273     274                         LEE KNOW, HAN (Stray Kids)
# 274     275              BANG CHAN, CHANGBIN, HAN (Stray Kids)
# 275     276                                   HAN (Stray Kids)
# 276     277              BANG CHAN, CHANGBIN, HAN (Stray Kids)
#
#                          title releasedate       album  \
# 0                   hellevator   11/1/2017     Mixtape
# 1                         GLOW    1/8/2018     Mixtape
# 2    grrrlawoftotalmadnessgrrr    1/8/2018     Mixtape
# 3                       YAYAYA    1/8/2018     Mixtape
# 4      어린 날개 (Spread My Wings)    1/8/2018     Mixtape
# ..                         ...         ...         ...
# 272                        NaN         NaN  SKZ-REPLAY
# 273                        NaN         NaN  SKZ-REPLAY
# 274                        NaN         NaN  SKZ-REPLAY
# 275                        NaN         NaN  SKZ-REPLAY
# 276                        NaN         NaN  SKZ-REPLAY
#
#                  cleaned_title
# 0                   hellevator
# 1                         glow
# 2    grrrlawoftotalmadnessgrrr
# 3                       yayaya
# 4                spreadmywings
# ..                         ...
# 272                    volcano
# 273                  wantsobad
# 274                       zone
# 275                      happy
# 276    allmylifestraykidsremix
#
# [269 rows x 6 columns]
